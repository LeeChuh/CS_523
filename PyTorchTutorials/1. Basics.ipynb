# %%
import numpy as np
import torch

# %%
x = torch.ones(5, device = 'mps')
y = torch.ones(5, device = 'cpu')
try:
    x.numpy()
except:
    print("numpy can only be stored in CPU, not GPU")
# Out:
# numpy can only be stored in CPU, not GPU

# %% [markdown]
# ### $requires-grad = True$ tells PyTorch we need to calculate the gradient of this tensor in the later step

# %%
a = torch.ones(5, requires_grad = True)
print(a)
# Out:
# tensor([1., 1., 1., 1., 1.], requires_grad=True)
